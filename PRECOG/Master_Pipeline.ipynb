# %% [markdown]
# # 🚀 Complete Trading Strategy Pipeline
# ## All 4 Parts Combined - Automated Execution
#
# This notebook runs all 4 parts of the trading strategy pipeline:
# 1. Data Cleaning & Feature Engineering
# 2. Model Training & Strategy
# 3. Backtesting & Analysis
# 4. Statistical Arbitrage
#
# ---

# %% [markdown]
# ## 📋 Setup: Upload Kaggle API Key

# %%
# Upload your kaggle.json file
from google.colab import files
print("📤 Please upload your kaggle.json file...")
uploaded = files.upload()

# Configure Kaggle
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
print("✅ Kaggle configured successfully!")

# %% [markdown]
# ## 📦 Install All Required Packages

# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn scipy statsmodels ta yfinance kaggle --quiet
print("✅ All packages installed!")

# %% [markdown]
# ## 📚 Import All Libraries

# %%
# Core Libraries
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (14, 6)
plt.rcParams['font.size'] = 12

# Statistical Analysis
from scipy import stats
from scipy.stats import zscore

# Technical Analysis
import ta
from ta.volatility import BollingerBands, AverageTrueRange
from ta.momentum import RSIIndicator, StochasticOscillator, ROCIndicator
from ta.trend import MACD, SMAIndicator, EMAIndicator, ADXIndicator
from ta.volume import VolumeWeightedAveragePrice, OnBalanceVolumeIndicator

# Sklearn for preprocessing
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.impute import SimpleImputer

print("✅ Libraries imported successfully!")
print(f"📅 Pipeline started: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %% [markdown]
# ---
# # 🎯 PART 1: Data Cleaning & Feature Engineering
# ---

# %% [markdown]
# ## Upload Part 1 Notebook
#
# **ACTION REQUIRED:**
# 1. Run this cell
# 2. Upload: `Part1_Data_Cleaning_Feature_Engineering.ipynb`

# %%
from google.colab import files
print("📤 Upload Part1_Data_Cleaning_Feature_Engineering.ipynb")
part1_file = files.upload()
print("✅ Part 1 uploaded!")

# %%
# Execute Part 1
print("\n" + "="*60)
print("🔄 EXECUTING PART 1: Data Cleaning & Feature Engineering")
print("="*60 + "\n")

# %run Part1_Data_Cleaning_Feature_Engineering.ipynb

print("\n" + "="*60)
print("✅ PART 1 COMPLETED!")
print("="*60 + "\n")

# %% [markdown]
# ---
# # 🎯 PART 2: Model Training & Strategy
# ---

# %% [markdown]
# ## Upload Part 2 Notebook
#
# **ACTION REQUIRED:**
# 1. Run this cell
# 2. Upload: `Part2_Model_Training_Strategy.ipynb`

# %%
from google.colab import files
print("📤 Upload Part2_Model_Training_Strategy.ipynb")
part2_file = files.upload()
print("✅ Part 2 uploaded!")

# %%
# Execute Part 2
print("\n" + "="*60)
print("🔄 EXECUTING PART 2: Model Training & Strategy")
print("="*60 + "\n")

# %run Part2_Model_Training_Strategy.ipynb

print("\n" + "="*60)
print("✅ PART 2 COMPLETED!")
print("="*60 + "\n")

# %% [markdown]
# ---
# # 🎯 PART 3: Backtesting & Analysis
# ---

# %% [markdown]
# ## Upload Part 3 Notebook
#
# **ACTION REQUIRED:**
# 1. Run this cell
# 2. Upload: `Part3_Backtesting_Analysis.ipynb`

# %%
from google.colab import files
print("📤 Upload Part3_Backtesting_Analysis.ipynb")
part3_file = files.upload()
print("✅ Part 3 uploaded!")

# %%
# Execute Part 3
print("\n" + "="*60)
print("🔄 EXECUTING PART 3: Backtesting & Analysis")
print("="*60 + "\n")

# %run Part3_Backtesting_Analysis.ipynb

print("\n" + "="*60)
print("✅ PART 3 COMPLETED!")
print("="*60 + "\n")

# %% [markdown]
# ---
# # 🎯 PART 4: Statistical Arbitrage
# ---

# %% [markdown]
# ## Upload Part 4 Notebook
#
# **ACTION REQUIRED:**
# 1. Run this cell
# 2. Upload: `Part4_Statistical_Arbitrage.ipynb`

# %%
from google.colab import files
print("📤 Upload Part4_Statistical_Arbitrage.ipynb")
part4_file = files.upload()
print("✅ Part 4 uploaded!")

# %%
# Execute Part 4
print("\n" + "="*60)
print("🔄 EXECUTING PART 4: Statistical Arbitrage")
print("="*60 + "\n")

# %run Part4_Statistical_Arbitrage.ipynb

print("\n" + "="*60)
print("✅ PART 4 COMPLETED!")
print("="*60 + "\n")

# %% [markdown]
# ---
# # 🎉 Pipeline Complete!
# ---

# %%
print("\n" + "="*70)
print("🎉 🎉 🎉  COMPLETE PIPELINE EXECUTION FINISHED!  🎉 🎉 🎉")
print("="*70)
print(f"\n⏰ Completed at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print("\n✅ All 4 parts have been executed successfully!")
print("\n📊 Check the outputs above for:")
print("   - Cleaned datasets")
print("   - Feature engineering results")
print("   - Model training metrics")
print("   - Backtesting performance")
print("   - Statistical arbitrage strategies")
print("\n💾 You can now download any generated files or results.")
print("="*70)
